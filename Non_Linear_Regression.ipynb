# %%
import pandas as pd

data = pd.read_csv("day.csv")
data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#Summary Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
# statistics information for numerical columns
data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
#Check missing values
data.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#IQR
q1 = data["casual"].quantile(0.25)
q3 = data["casual"].quantile(0.75)

iqr = q3-q1 
fence_low  = q1-1.5*iqr
fence_high = q3+1.5*iqr

data.loc[(data["casual"] < fence_low) | (data["casual"] > fence_high)]
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 148      149  2011-05-29       2   0     5        0        0           0
# 183      184  2011-07-03       3   0     7        0        0           0
# 184      185  2011-07-04       3   0     7        1        1           0
# 196      197  2011-07-16       3   0     7        0        6           0
# 246      247  2011-09-04       3   0     9        0        0           0
# 281      282  2011-10-09       4   0    10        0        0           0
# 441      442  2012-03-17       1   1     3        0        6           0
# 447      448  2012-03-23       2   1     3        0        5           1
# 455      456  2012-03-31       2   1     3        0        6           0
# 456      457  2012-04-01       2   1     4        0        0           0
# 462      463  2012-04-07       2   1     4        0        6           0
# 469      470  2012-04-14       2   1     4        0        6           0
# ...

# %%
#IQR
q1 = data["cnt"].quantile(0.25)
q3 = data["cnt"].quantile(0.75)

iqr = q3-q1 
fence_low  = q1-1.5*iqr
fence_high = q3+1.5*iqr

data.loc[(data["cnt"] < fence_low) | (data["cnt"] > fence_high)]
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
#Handle Outliers
df_clean = data.loc[(data["casual"] >= fence_low) & (data["casual"] <= fence_high)]

df_clean
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
import numpy as np
x = np.array(df_clean['cnt'])
y = np.array(df_clean['casual'])

# %%
#mengubah data tabel
m = len(y)
sum_x = np.sum(x) 
sum_x2 =  np.sum(x*x)

ln_y = np.log(y) 
sum_ln_y = np.sum(ln_y) 
sum_xln_y =  np.sum(x*ln_y)

# %%
# matriks
A = np.array([[m,sum_x],[sum_x, sum_x2]])
print(A)
b = np.array([sum_ln_y, sum_xln_y])
print(b)
# Out:
# [[        731     3292679]
#  [    3292679 17570910217]]
# [4.64024361e+03 2.19939995e+07]

# %%
# koefisien
c = np.linalg.inv(A)@b
print('Coefficients:')
print(c)
# Out:
# Coefficients:
# [4.55114440e+00 3.98871877e-04]

# %%
# fungsi non linear
def Non_reg(a1,a0,x):
  return np.exp(a0)*np.exp(a1*x)

# %%
import matplotlib.pyplot as plt 
xp = np.linspace(min(x), max(x), 100)
yp = Non_reg(c[1],c[0],xp)

plt.plot(xp,yp, color = 'red', linewidth=3)
plt.scatter(x,y,  color='blue')
plt.xlabel("x")
plt.ylabel("y")
plt.legend(('$\hat{y}(x)=b e^{ax}$',), loc='center left')
plt.grid()
plt.show()
